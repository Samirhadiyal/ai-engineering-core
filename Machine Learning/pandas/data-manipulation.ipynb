# %% [markdown]
# # Series

# %%
import pandas as pd


sr = pd.Series(["BWM", "AUDI"])
print(sr)
# Out:
# 0     BWM
# 1    AUDI
# dtype: object

# %% [markdown]
# # DataFrame

# %%
dataf = pd.DataFrame({"Car": ["Toyota","Honda","BMW"], "Colour": ["White","Black","Red"]})
dataf
# Out:
#       Car Colour
# 0  Toyota  White
# 1   Honda  Black
# 2     BMW    Red

# %%
cardata = pd.read_csv("car_data.csv")
cardata
# Out:
#           name    country   price  distance  seats  door
# 0          bmw  Australia  100000    150043      5     4
# 1     mercedes   Malaysia  200000     87899      5     4
# 2         i 10    Bahrain  306000     32539      5     4
# 3         i 20      Spain  453330     11344      5     4
# 4        swift     Turkey  800000    213099      5     4
# 5    ambesator     Monaco  334900     91941      5     4
# 6  range rover     Canada  890000     28941      5     4
# 7   land rover     France  250000     97385      5     4
# 8        gimni         UK   40000     60000      5     4
# 9       pagani    Germany  199000     31500      5     4

# %%
cardata.dtypes
# Out:
# name        object
# country     object
# price        int64
# distance     int64
# seats        int64
# door         int64
# dtype: object

# %%
cardata.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
cardata.describe()
# Out:
#                price       distance  seats  door
# count      10.000000      10.000000   10.0  10.0
# mean   357323.000000   80469.100000    5.0   4.0
# std    282902.777884   62762.204963    0.0   0.0
# min     40000.000000   11344.000000    5.0   4.0
# 25%    199250.000000   31759.750000    5.0   4.0
# 50%    278000.000000   73949.500000    5.0   4.0
# 75%    423722.500000   96024.000000    5.0   4.0
# max    890000.000000  213099.000000    5.0   4.0

# %%
cardata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      10 non-null     object
#  1   country   10 non-null     object
#  2   price     10 non-null     int64
#  3   distance  10 non-null     int64
#  4   seats     10 non-null     int64
#  5   door      10 non-null     int64
# dtypes: int64(4), object(2)
# memory usage: 612.0+ bytes

# %%
cardata["price"].mean()
# Out:
# np.float64(357323.0)

# %%
cardata["price"].sum()
# Out:
# np.int64(3573230)

# %%
len(cardata)
# Out:
# 10

# %%
cardata.head()
# Out:
#        name    country   price  distance  seats  door
# 0       bmw  Australia  100000    150043      5     4
# 1  mercedes   Malaysia  200000     87899      5     4
# 2      i 10    Bahrain  306000     32539      5     4
# 3      i 20      Spain  453330     11344      5     4
# 4     swift     Turkey  800000    213099      5     4

# %%
cardata.tail()
# Out:
#           name  country   price  distance  seats  door
# 5    ambesator   Monaco  334900     91941      5     4
# 6  range rover   Canada  890000     28941      5     4
# 7   land rover   France  250000     97385      5     4
# 8        gimni       UK   40000     60000      5     4
# 9       pagani  Germany  199000     31500      5     4

# %%
animal = pd.Series(["cat", "dog", "wolf", "lion", "panda"],
                   index = [1,5,3,4,5])

# %%
animal
# Out:
# 1      cat
# 5      dog
# 3     wolf
# 4     lion
# 5    panda
# dtype: object

# %%
animal.loc[5]
# Out:
# 5      dog
# 5    panda
# dtype: object

# %%
animal.iloc[2]
# Out:
# 'wolf'

# %%
cardata.loc[3]
# Out:
# name          i 20
# country      Spain
# price       453330
# distance     11344
# seats            5
# door             4
# Name: 3, dtype: object

# %%
cardata.head(2)
# Out:
#        name    country   price  distance  seats  door
# 0       bmw  Australia  100000    150043      5     4
# 1  mercedes   Malaysia  200000     87899      5     4

# %%
cardata["name"]
# Out:
# 0            bmw
# 1       mercedes
# 2           i 10
# 3           i 20
# 4          swift
# 5      ambesator
# 6    range rover
# 7     land rover
# 8          gimni
# 9         pagani
# Name: name, dtype: object

# %%
cardata[cardata["price"] > 200000]
# Out:
#           name  country   price  distance  seats  door
# 2         i 10  Bahrain  306000     32539      5     4
# 3         i 20    Spain  453330     11344      5     4
# 4        swift   Turkey  800000    213099      5     4
# 5    ambesator   Monaco  334900     91941      5     4
# 6  range rover   Canada  890000     28941      5     4
# 7   land rover   France  250000     97385      5     4

# %%
cardata["price"].plot()
# Out:
# <Axes: >

# %%
cardata
# Out:
#           name    country   price  distance  seats  door
# 0          bmw  Australia  100000    150043      5     4
# 1     mercedes   Malaysia  200000     87899      5     4
# 2         i 10    Bahrain  306000     32539      5     4
# 3         i 20      Spain  453330     11344      5     4
# 4        swift     Turkey  800000    213099      5     4
# 5    ambesator     Monaco  334900     91941      5     4
# 6  range rover     Canada  890000     28941      5     4
# 7   land rover     France  250000     97385      5     4
# 8        gimni         UK   40000     60000      5     4
# 9       pagani    Germany  199000     31500      5     4

# %%
cardata["name"].str.lower()
# Out:
# 0            bmw
# 1       mercedes
# 2           i 10
# 3           i 20
# 4          swift
# 5      ambesator
# 6    range rover
# 7     land rover
# 8          gimni
# 9         pagani
# Name: name, dtype: object

# %%
# to save the changes in column of the main data, we can reassign that column

# %%
cardata["name"] = cardata["name"].str.lower()
cardata
# Out:
#           name    country   price  distance  seats  door
# 0          bmw  Australia  100000    150043      5     4
# 1     mercedes   Malaysia  200000     87899      5     4
# 2         i 10    Bahrain  306000     32539      5     4
# 3         i 20      Spain  453330     11344      5     4
# 4        swift     Turkey  800000    213099      5     4
# 5    ambesator     Monaco  334900     91941      5     4
# 6  range rover     Canada  890000     28941      5     4
# 7   land rover     France  250000     97385      5     4
# 8        gimni         UK   40000     60000      5     4
# 9       pagani    Germany  199000     31500      5     4

# %%
carmissdata = pd.read_csv("car_missingdata.csv")
carmissdata
# Out:
#           name      location    country     price
# 0          BMW     Melbourne  Australia  100000.0
# 1     Mercedes  Kuala Lumpur        NaN  200000.0
# 2         i 10        Sakhir    Bahrain       NaN
# 3         I 20           NaN      Spain       NaN
# 4        Swift      Istanbul     Turkey  800000.0
# 5    Ambesator         India        NaN  334900.0
# 6  Range Rover      Montreal     Canada  890000.0
# 7   Land Rover           NaN     France       NaN
# 8        Gimni   Silverstone         UK   40000.0
# 9          NaN    Hockenheim        NaN  199000.0

# %% [markdown]
# # Missing Values

# %%
carmissdata["price"].mean().round(2)
# Out:
# np.float64(366271.43)

# %%
carmissdata["price"].fillna(carmissdata["price"].mean().round(2))
# Out:
# 0    100000.00
# 1    200000.00
# 2    366271.43
# 3    366271.43
# 4    800000.00
# 5    334900.00
# 6    890000.00
# 7    366271.43
# 8     40000.00
# 9    199000.00
# Name: price, dtype: float64

# %%
# to save the changes in column of the main data, we can just add inplace=True

# %%
carmissdata["price"].fillna(carmissdata["price"].mean(), inplace=True)
# Out:
# C:\Users\kisha\AppData\Local\Temp\ipykernel_21852\3073810268.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   carmissdata["price"].fillna(carmissdata["price"].mean(), inplace=True)

# %%
carmissdata
# Out:
#           name      location    country          price
# 0          BMW     Melbourne  Australia  100000.000000
# 1     Mercedes  Kuala Lumpur        NaN  200000.000000
# 2         i 10        Sakhir    Bahrain  366271.428571
# 3         I 20           NaN      Spain  366271.428571
# 4        Swift      Istanbul     Turkey  800000.000000
# 5    Ambesator         India        NaN  334900.000000
# 6  Range Rover      Montreal     Canada  890000.000000
# 7   Land Rover           NaN     France  366271.428571
# 8        Gimni   Silverstone         UK   40000.000000
# 9          NaN    Hockenheim        NaN  199000.000000

# %%
carmissdata.dropna()
# Out:
#           name     location    country          price
# 0          BMW    Melbourne  Australia  100000.000000
# 2         i 10       Sakhir    Bahrain  366271.428571
# 4        Swift     Istanbul     Turkey  800000.000000
# 6  Range Rover     Montreal     Canada  890000.000000
# 8        Gimni  Silverstone         UK   40000.000000

# %%
carmissdata
# Out:
#           name      location    country          price
# 0          BMW     Melbourne  Australia  100000.000000
# 1     Mercedes  Kuala Lumpur        NaN  200000.000000
# 2         i 10        Sakhir    Bahrain  366271.428571
# 3         I 20           NaN      Spain  366271.428571
# 4        Swift      Istanbul     Turkey  800000.000000
# 5    Ambesator         India        NaN  334900.000000
# 6  Range Rover      Montreal     Canada  890000.000000
# 7   Land Rover           NaN     France  366271.428571
# 8        Gimni   Silverstone         UK   40000.000000
# 9          NaN    Hockenheim        NaN  199000.000000

# %%
carmissdata.dropna(inplace=True)

# %%
carmissdata
# Out:
#           name     location    country          price
# 0          BMW    Melbourne  Australia  100000.000000
# 2         i 10       Sakhir    Bahrain  366271.428571
# 4        Swift     Istanbul     Turkey  800000.000000
# 6  Range Rover     Montreal     Canada  890000.000000
# 8        Gimni  Silverstone         UK   40000.000000

# %%
carmiss = pd.read_csv("car_missingdata.csv")
carmiss
# Out:
#           name      location    country     price
# 0          BMW     Melbourne  Australia  100000.0
# 1     Mercedes  Kuala Lumpur        NaN  200000.0
# 2         i 10        Sakhir    Bahrain       NaN
# 3         I 20           NaN      Spain       NaN
# 4        Swift      Istanbul     Turkey  800000.0
# 5    Ambesator         India        NaN  334900.0
# 6  Range Rover      Montreal     Canada  890000.0
# 7   Land Rover           NaN     France       NaN
# 8        Gimni   Silverstone         UK   40000.0
# 9          NaN    Hockenheim        NaN  199000.0

# %%
carmiss_dropped = carmiss.dropna()
carmiss_dropped
# Out:
#           name     location    country     price
# 0          BMW    Melbourne  Australia  100000.0
# 4        Swift     Istanbul     Turkey  800000.0
# 6  Range Rover     Montreal     Canada  890000.0
# 8        Gimni  Silverstone         UK   40000.0

# %%
cardata
# Out:
#           name    country   price  distance  seats  door
# 0          bmw  Australia  100000    150043      5     4
# 1     mercedes   Malaysia  200000     87899      5     4
# 2         i 10    Bahrain  306000     32539      5     4
# 3         i 20      Spain  453330     11344      5     4
# 4        swift     Turkey  800000    213099      5     4
# 5    ambesator     Monaco  334900     91941      5     4
# 6  range rover     Canada  890000     28941      5     4
# 7   land rover     France  250000     97385      5     4
# 8        gimni         UK   40000     60000      5     4
# 9       pagani    Germany  199000     31500      5     4

# %%
cardata["distance"] = [150043, 87899, 32539, 11344, 213099, 91941, 28941, 97385, 60000, 31500]
cardata.to_csv("car_data.csv")
cardata
# Out:
#           name    country   price  distance  seats  door
# 0          bmw  Australia  100000    150043      5     4
# 1     mercedes   Malaysia  200000     87899      5     4
# 2         i 10    Bahrain  306000     32539      5     4
# 3         i 20      Spain  453330     11344      5     4
# 4        swift     Turkey  800000    213099      5     4
# 5    ambesator     Monaco  334900     91941      5     4
# 6  range rover     Canada  890000     28941      5     4
# 7   land rover     France  250000     97385      5     4
# 8        gimni         UK   40000     60000      5     4
# 9       pagani    Germany  199000     31500      5     4

# %% [markdown]
# # Column From Series

# %%
seats_column = pd.Series([5,5,5,5,5,5])

cardata["seats"] = seats_column
cardata
# Out:
#           name    country   price  distance  seats  door
# 0          bmw  Australia  100000    150043    5.0     4
# 1     mercedes   Malaysia  200000     87899    5.0     4
# 2         i 10    Bahrain  306000     32539    5.0     4
# 3         i 20      Spain  453330     11344    5.0     4
# 4        swift     Turkey  800000    213099    5.0     4
# 5    ambesator     Monaco  334900     91941    5.0     4
# 6  range rover     Canada  890000     28941    NaN     4
# 7   land rover     France  250000     97385    NaN     4
# 8        gimni         UK   40000     60000    NaN     4
# 9       pagani    Germany  199000     31500    NaN     4

# %%
cardata["seats"].fillna(cardata["seats"].mean(), inplace=True)
# Out:
# C:\Users\kisha\AppData\Local\Temp\ipykernel_21852\3954082395.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   cardata["seats"].fillna(cardata["seats"].mean(), inplace=True)

# %%
cardata
# Out:
#           name    country   price  distance  seats  door
# 0          bmw  Australia  100000    150043    5.0     4
# 1     mercedes   Malaysia  200000     87899    5.0     4
# 2         i 10    Bahrain  306000     32539    5.0     4
# 3         i 20      Spain  453330     11344    5.0     4
# 4        swift     Turkey  800000    213099    5.0     4
# 5    ambesator     Monaco  334900     91941    5.0     4
# 6  range rover     Canada  890000     28941    5.0     4
# 7   land rover     France  250000     97385    5.0     4
# 8        gimni         UK   40000     60000    5.0     4
# 9       pagani    Germany  199000     31500    5.0     4

# %% [markdown]
# # Column from list

# %%
doors_column = [4,4,4,4,4,4,4,4,4,4]

cardata["door"] = doors_column
cardata
# Out:
#           name    country   price  distance  seats  door
# 0          bmw  Australia  100000    150043    5.0     4
# 1     mercedes   Malaysia  200000     87899    5.0     4
# 2         i 10    Bahrain  306000     32539    5.0     4
# 3         i 20      Spain  453330     11344    5.0     4
# 4        swift     Turkey  800000    213099    5.0     4
# 5    ambesator     Monaco  334900     91941    5.0     4
# 6  range rover     Canada  890000     28941    5.0     4
# 7   land rover     France  250000     97385    5.0     4
# 8        gimni         UK   40000     60000    5.0     4
# 9       pagani    Germany  199000     31500    5.0     4

# %%
fule_column = [5.5, 9.5, 6.0, 7.5, 8.9, 3.4, 0.3, 4.0, 7.7, 6.7]

cardata["fule per 100KM"] = fule_column
cardata
# Out:
#           name    country   price  distance  seats  door  fule per 100KM
# 0          bmw  Australia  100000    150043    5.0     4             5.5
# 1     mercedes   Malaysia  200000     87899    5.0     4             9.5
# 2         i 10    Bahrain  306000     32539    5.0     4             6.0
# 3         i 20      Spain  453330     11344    5.0     4             7.5
# 4        swift     Turkey  800000    213099    5.0     4             8.9
# 5    ambesator     Monaco  334900     91941    5.0     4             3.4
# 6  range rover     Canada  890000     28941    5.0     4             0.3
# 7   land rover     France  250000     97385    5.0     4             4.0
# 8        gimni         UK   40000     60000    5.0     4             7.7
# 9       pagani    Germany  199000     31500    5.0     4             6.7

# %%
cardata["total fule used"] = cardata["distance"] / 100 * cardata["fule per 100KM"]

# %%
cardata
# Out:
#           name    country   price  distance  seats  door  fule per 100KM  \
# 0          bmw  Australia  100000    150043    5.0     4             5.5
# 1     mercedes   Malaysia  200000     87899    5.0     4             9.5
# 2         i 10    Bahrain  306000     32539    5.0     4             6.0
# 3         i 20      Spain  453330     11344    5.0     4             7.5
# 4        swift     Turkey  800000    213099    5.0     4             8.9
# 5    ambesator     Monaco  334900     91941    5.0     4             3.4
# 6  range rover     Canada  890000     28941    5.0     4             0.3
# 7   land rover     France  250000     97385    5.0     4             4.0
# 8        gimni         UK   40000     60000    5.0     4             7.7
# 9       pagani    Germany  199000     31500    5.0     4             6.7
#
#    total fule used
# 0         8252.365
# 1         8350.405
# 2         1952.340
# 3          850.800
# 4        18965.811
# 5         3125.994
# 6           86.823
# ...

# %% [markdown]
# # column from single value

# %%
cardata["number of wheels"] = 4
cardata
# Out:
#           name    country   price  distance  seats  door  fule per 100KM  \
# 0          bmw  Australia  100000    150043    5.0     4             5.5
# 1     mercedes   Malaysia  200000     87899    5.0     4             9.5
# 2         i 10    Bahrain  306000     32539    5.0     4             6.0
# 3         i 20      Spain  453330     11344    5.0     4             7.5
# 4        swift     Turkey  800000    213099    5.0     4             8.9
# 5    ambesator     Monaco  334900     91941    5.0     4             3.4
# 6  range rover     Canada  890000     28941    5.0     4             0.3
# 7   land rover     France  250000     97385    5.0     4             4.0
# 8        gimni         UK   40000     60000    5.0     4             7.7
# 9       pagani    Germany  199000     31500    5.0     4             6.7
#
#    total fule used  number of wheels
# 0         8252.365                 4
# 1         8350.405                 4
# 2         1952.340                 4
# ...

# %%
# using sample function like ///sample(3)\\\ it will return any 3 rows of data, ///sample(frac=0.5)\\\ it will return 5% of data

# %%
#cardata.sample(frac=1)

# %%
# if index is shuffled ///reset.index()\\\ gets it in order

# %%
# cardata.reset_index()

# %%
cardata.drop(["level_0", "Unnamed: 0", "index"], axis=1, inplace=True, errors="ignore")

# %%
cardata
# Out:
#           name    country   price  distance  seats  door  fule per 100KM  \
# 0          bmw  Australia  100000    150043    5.0     4             5.5
# 1     mercedes   Malaysia  200000     87899    5.0     4             9.5
# 2         i 10    Bahrain  306000     32539    5.0     4             6.0
# 3         i 20      Spain  453330     11344    5.0     4             7.5
# 4        swift     Turkey  800000    213099    5.0     4             8.9
# 5    ambesator     Monaco  334900     91941    5.0     4             3.4
# 6  range rover     Canada  890000     28941    5.0     4             0.3
# 7   land rover     France  250000     97385    5.0     4             4.0
# 8        gimni         UK   40000     60000    5.0     4             7.7
# 9       pagani    Germany  199000     31500    5.0     4             6.7
#
#    total fule used  number of wheels
# 0         8252.365                 4
# 1         8350.405                 4
# 2         1952.340                 4
# ...

# %%
# ///apply()\\\ this function get used when we want to perform any kinda function on a specific column

# %%
cardata["distance"] = cardata["distance"].apply(lambda x: x / 1.6)   # here x is value of column distance, which is devided by 1.6
cardata
# Out:
#           name    country   price      distance  seats  door  fule per 100KM  \
# 0          bmw  Australia  100000  58610.546875    5.0     4             5.5
# 1     mercedes   Malaysia  200000  34335.546875    5.0     4             9.5
# 2         i 10    Bahrain  306000  12710.546875    5.0     4             6.0
# 3         i 20      Spain  453330   4431.250000    5.0     4             7.5
# 4        swift     Turkey  800000  83241.796875    5.0     4             8.9
# 5    ambesator     Monaco  334900  35914.453125    5.0     4             3.4
# 6  range rover     Canada  890000  11305.078125    5.0     4             0.3
# 7   land rover     France  250000  38041.015625    5.0     4             4.0
# 8        gimni         UK   40000  23437.500000    5.0     4             7.7
# 9       pagani    Germany  199000  12304.687500    5.0     4             6.7
#
#    total fule used  number of wheels  disrance
# 0         8252.365                 4    150043
# ...
